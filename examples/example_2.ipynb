# %% [markdown]
# ## Process Flow (Activities to Extract):
#
# 1. Purchase Order Submitted - Sarah Chen initiates order
# 2. Quote Confirmed - Jennifer Martinez from Titan Precast
# 3. Production Approved - Tom R (engineer) reviews specs
# 4. Production Started - Marcus Johnson supervising
# 5. Quality Control Inspection - Carlos Rodriguez inspects
# 6. Shipment Scheduled - Logistics assigns Polaris Shipping
# 7. Loaded for Delivery - Pete from warehouse
# 8. Shipment Delayed - Traffic incident causes delay
# 9. Delay Notification - Jim Patterson calls (wrong contact!)
# 10. Customer Response - Sarah Chen clarifies contact info
# 11. Delivered - Mike Torres receives at job site
# 12. Installed - Danny Wu (crane operator) installs footers
# 13. Site Inspection - Linda Kowalski approves
# 14. Invoice Generated - Final billing
#
# ## NLP Challenges Built In:
#
# * Order ID variations: "#234123", "234-123", "two-three-four-one-two-three", "order 234123"
# * Multiple resources: Sarah Chen, Jennifer Martinez, Tom R, Marcus Johnson, Carlos Rodriguez, Jim Patterson, Pete, Mike Torres, Danny Wu, Linda Kowalski, Frank
# * Mixed formats: Emails, voicemails, production logs, inspection reports, invoices, informal notes
# * Inconsistent capitalization: "order #234123" vs "Order: 234123" vs "PO 234123"
# * Wrong contact info: Jim calls "Mike" but it's Sarah's order (realistic confusion!)
# * Casual language: "ughhh", informal signatures like "- warehouse guy (pete)"
# * Multiple timestamps formats: Various date/time representations
# * Implied events: Some activities aren't explicitly named but must be inferred

# %%
import json
import pathlib
import pm4py
import pandas as pd
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_anthropic import ChatAnthropic
from pydantic import BaseModel
from dotenv import load_dotenv
import getpass
import os
from IPython.display import HTML, display

# %%
# Setup the pydantic class to validate output
class output_format(BaseModel):
    """
    Columns required by PM4Py:
    - case:concept:name (string or int): identifies the process instance
    - concept:name (string): the activity name
    - time:timestamp (datetime): when the event occurred
    """

    case_concept_name: str
    concept_name: str


# Configure the JSON output parser
output_parser = JsonOutputParser(pydantic_object=output_format)

# Create the prompt template
prompt = PromptTemplate(
    template="""Extract the following information from this event text:
1. case_concept_name: The order number or case identifier (normalize variations like "#234123", "234-123", "two-three-four-one-two-three" to just "234123")
2. concept_name: A concise activity name describing what happened (e.g., "Purchase Order Submitted", "Production Started", "Delivered")

Event text:
{event_text}

{format_instructions}""",
    input_variables=["event_text"],
    partial_variables={"format_instructions": output_parser.get_format_instructions()},
)

# Configure LLM
load_dotenv()
if "ANTHROPIC_API_KEY" not in os.environ:
    os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter your Anthropic API key: ")
llm = ChatAnthropic(model="claude-haiku-4-5", temperature=0)

# Create the chain
chain = prompt | llm | output_parser

# Test with a single event
test_event = {
    "content": "Purchase order submitted by Sarah Chen - Springfield Mega Mall Construction Project. Need 12 precast concrete footers, spec F-2400x800x600mm. Order ref: #234123. Budget approved by Frank in accounting. Rush delivery requested for Phase 2 foundation work.",
    "timestamp": "2011-01-01T09:15:23.000+01:00",
}

print("Testing with first event:")
print(f"Content: {test_event['content'][:100]}...")
print()

result = chain.invoke({"event_text": test_event["content"]})
print("Extracted:")
print(json.dumps(result, indent=2))
# Out:
# Testing with first event:
# Content: Purchase order submitted by Sarah Chen - Springfield Mega Mall Construction Project. Need 12 precast...
#
# Extracted:
# {
#   "case_concept_name": "234123",
#   "concept_name": "Purchase Order Submitted"
# }

# %% [markdown]
# # Classify the Events

# %%
# load the sample events
working_directory = pathlib.Path().resolve()
with open(f"{working_directory}/example_2.json") as file:
    data = json.load(file)

# Process all events and build the DataFrame
parsed_events = []

for event in data["events"]:
    try:
        # Extract case_id, activity, and resource using the LLM chain
        extracted = chain.invoke({"event_text": event["content"]})

        # Add to our list with the timestamp
        parsed_events.append(
            {
                "case:concept:name": extracted.get("case_concept_name"),
                "concept:name": extracted.get("concept_name"),
                "time:timestamp": event["timestamp"],
            }
        )

        print(f"Processed: {extracted.get('concept_name', 'Unknown')[:40]}")

    except Exception as e:
        print(f"Error processing event: {e}")
        # Add a placeholder for failed events
        parsed_events.append(
            {
                "case:concept:name": "UNKNOWN",
                "concept:name": "PARSE_ERROR",
                "time:timestamp": event["timestamp"],
            }
        )

# Create DataFrame
parsed_events_df = pd.DataFrame(parsed_events)
parsed_events_df["time:timestamp"] = pd.to_datetime(parsed_events_df["time:timestamp"])
print(f"\nProcessed {len(parsed_events_df)} events")
parsed_events_df
# Out:
# Processed: Purchase Order Submitted
# Processed: Quote Confirmation
# Processed: Order Approved for Production
# Processed: Production Started
# Processed: QC Inspection Report
# Processed: Shipment Scheduled
# Processed: Loaded onto Truck
# Processed: Delivery Delayed
# Processed: Order Delayed
# Processed: Delivery Delay Confirmed
# Processed: Delivery Confirmed
# Processed: Foundation Footers Installed
# Processed: Foundation Inspection Approved
# Processed: Invoice Issued
#
# Processed 14 events
#    case:concept:name                    concept:name            time:timestamp
# 0             234123        Purchase Order Submitted 2011-01-01 09:15:23+01:00
# 1             234123              Quote Confirmation 2011-01-01 14:32:00+01:00
# 2             234123   Order Approved for Production 2011-01-02 08:45:00+01:00
# 3             234123              Production Started 2011-01-03 06:30:00+01:00
# 4             234123            QC Inspection Report 2011-01-04 15:20:00+01:00
# 5             234123              Shipment Scheduled 2011-01-05 11:05:00+01:00
# 6             234123               Loaded onto Truck 2011-01-06 07:22:00+01:00
# 7             234123                Delivery Delayed 2011-01-06 14:15:00+01:00
# 8             234123                   Order Delayed 2011-01-08 12:05:00+01:00
# 9             234123        Delivery Delay Confirmed 2011-01-08 13:47:00+01:00
# 10            234123              Delivery Confirmed 2011-01-08 13:35:00+01:00
# 11            234123    Foundation Footers Installed 2011-01-08 17:20:00+01:00
# 12            234123  Foundation Inspection Approved 2011-01-10 10:15:00+01:00
# 13            234123                  Invoice Issued 2011-01-10 16:30:00+01:00

# %% [markdown]
# # Run the Process Mining Algorithm
# Viualize the workflow as a Directly-Follows Graph (DFG) with performance metrics. Shows the average time between activities

# %%
# Discover performance DFG - returns tuple (dfg_dict, start_activities, end_activities)
performance_dfg, start_activities, end_activities = pm4py.discover_performance_dfg(log=parsed_events_df)

# Visualize with performance (time) annotations
output_file = f"{working_directory}/example_2_dfg_performance.svg"
pm4py.save_vis_performance_dfg(
    performance_dfg,
    start_activities,
    end_activities,
    str(output_file),
    rankdir="TB",
)
print(f"Performance DFG saved to: {output_file}")

# Display
with open(output_file, "r") as f:
    svg_content = f.read()
    display(HTML(svg_content))
# Out:
# Performance DFG saved to: /home/garre/development/process-mining-demo/examples/example_2_dfg_performance.svg
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="221pt" height="1364pt"
#  viewBox="0.00 0.00 221.00 1363.94" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1359.94)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-1359.94 217,-1359.94 217,4 -4,4"/>
# <!-- 9076218632175360295 -->
# <g id="node1" class="node">
# <title>9076218632175360295</title>
# <polygon fill="none" stroke="black" points="195.5,-1252.47 17.5,-1252.47 17.5,-1216.47 195.5,-1216.47 195.5,-1252.47"/>
# <text text-anchor="middle" x="106.5" y="-1231.37" font-family="Times,serif" font-size="12.00">Purchase Order Submitted</text>
# </g>
# <!-- &#45;6309557132471350034 -->
# <g id="node2" class="node">
# <title>&#45;6309557132471350034</title>
# <polygon fill="none" stroke="black" points="175,-1167.47 38,-1167.47 38,-1131.47 175,-1131.47 175,-1167.47"/>
# <text text-anchor="middle" x="106.5" y="-1146.37" font-family="Times,serif" font-size="12.00">Quote Confirmation</text>
# </g>
# <!-- 9076218632175360295&#45;&gt;&#45;6309557132471350034 -->
# <g id="edge1" class="edge">
# <title>9076218632175360295&#45;&gt;&#45;6309557132471350034</title>
# <path fill="none" stroke="#1c00e2" stroke-width="1.18" d="M106.5,-1216.27C106.5,-1205.14 106.5,-1190.41 106.5,-1177.71"/>
# <polygon fill="#1c00e2" stroke="#1c00e2" stroke-width="1.18" points="110,-1177.64 106.5,-1167.64 103,-1177.64 110,-1177.64"/>
# <text text-anchor="middle" x="114.5" y="-1188.87" font-family="Times,serif" font-size="12.00">5h</text>
# </g>
# <!-- &#45;6722472106916484854 -->
# <g id="node3" class="node">
# <title>&#45;6722472106916484854</title>
# <polygon fill="none" stroke="black" points="210,-1082.47 3,-1082.47 3,-1046.47 210,-1046.47 210,-1082.47"/>
# <text text-anchor="middle" x="106.5" y="-1061.37" font-family="Times,serif" font-size="12.00">Order Approved for Production</text>
# </g>
# <!-- &#45;6309557132471350034&#45;&gt;&#45;6722472106916484854 -->
# <g id="edge2" class="edge">
# <title>&#45;6309557132471350034&#45;&gt;&#45;6722472106916484854</title>
# <path fill="none" stroke="#64009a" stroke-width="1.64" d="M106.5,-1131.27C106.5,-1120.14 106.5,-1105.41 106.5,-1092.71"/>
# <polygon fill="#64009a" stroke="#64009a" stroke-width="1.64" points="110,-1092.64 106.5,-1082.64 103,-1092.64 110,-1092.64"/>
# <text text-anchor="middle" x="118" y="-1103.87" font-family="Times,serif" font-size="12.00">18h</text>
# </g>
# <!-- 9211802696541496642 -->
# <g id="node4" class="node">
# <title>9211802696541496642</title>
# <polygon fill="none" stroke="black" points="172.5,-997.47 40.5,-997.47 40.5,-961.47 172.5,-961.47 172.5,-997.47"/>
# <text text-anchor="middle" x="106.5" y="-976.37" font-family="Times,serif" font-size="12.00">Production Started</text>
# </g>
# <!-- &#45;6722472106916484854&#45;&gt;9211802696541496642 -->
# <g id="edge3" class="edge">
# <title>&#45;6722472106916484854&#45;&gt;9211802696541496642</title>
# <path fill="none" stroke="#780086" stroke-width="1.76" d="M106.5,-1046.27C106.5,-1035.14 106.5,-1020.41 106.5,-1007.71"/>
# <polygon fill="#780086" stroke="#780086" stroke-width="1.76" points="110,-1007.64 106.5,-997.64 103,-1007.64 110,-1007.64"/>
# <text text-anchor="middle" x="118" y="-1018.87" font-family="Times,serif" font-size="12.00">21h</text>
# </g>
# <!-- &#45;257823578152294650 -->
# <g id="node5" class="node">
# <title>&#45;257823578152294650</title>
# <polygon fill="none" stroke="black" points="179.5,-912.47 33.5,-912.47 33.5,-876.47 179.5,-876.47 179.5,-912.47"/>
# <text text-anchor="middle" x="106.5" y="-891.37" font-family="Times,serif" font-size="12.00">QC Inspection Report</text>
# </g>
# <!-- 9211802696541496642&#45;&gt;&#45;257823578152294650 -->
# <g id="edge4" class="edge">
# <title>9211802696541496642&#45;&gt;&#45;257823578152294650</title>
# <path fill="none" stroke="#b60048" stroke-width="2.15" d="M106.5,-961.27C106.5,-950.14 106.5,-935.41 106.5,-922.71"/>
# <polygon fill="#b60048" stroke="#b60048" stroke-width="2.15" points="110,-922.64 106.5,-912.64 103,-922.64 110,-922.64"/>
# <text text-anchor="middle" x="115.5" y="-933.87" font-family="Times,serif" font-size="12.00">1D</text>
# </g>
# <!-- &#45;2332445216433733546 -->
# <g id="node6" class="node">
# <title>&#45;2332445216433733546</title>
# <polygon fill="none" stroke="black" points="176.5,-827.47 36.5,-827.47 36.5,-791.47 176.5,-791.47 176.5,-827.47"/>
# <text text-anchor="middle" x="106.5" y="-806.37" font-family="Times,serif" font-size="12.00">Shipment Scheduled</text>
# </g>
# <!-- &#45;257823578152294650&#45;&gt;&#45;2332445216433733546 -->
# <g id="edge5" class="edge">
# <title>&#45;257823578152294650&#45;&gt;&#45;2332445216433733546</title>
# <path fill="none" stroke="#6d0091" stroke-width="1.69" d="M106.5,-876.27C106.5,-865.14 106.5,-850.41 106.5,-837.71"/>
# <polygon fill="#6d0091" stroke="#6d0091" stroke-width="1.69" points="110,-837.64 106.5,-827.64 103,-837.64 110,-837.64"/>
# <text text-anchor="middle" x="118" y="-848.87" font-family="Times,serif" font-size="12.00">19h</text>
# </g>
# <!-- 5332329727705121048 -->
# <g id="node7" class="node">
# <title>5332329727705121048</title>
# <polygon fill="none" stroke="black" points="172.5,-742.47 40.5,-742.47 40.5,-706.47 172.5,-706.47 172.5,-742.47"/>
# <text text-anchor="middle" x="106.5" y="-721.37" font-family="Times,serif" font-size="12.00">Loaded onto Truck</text>
# </g>
# <!-- &#45;2332445216433733546&#45;&gt;5332329727705121048 -->
# <g id="edge6" class="edge">
# <title>&#45;2332445216433733546&#45;&gt;5332329727705121048</title>
# <path fill="none" stroke="#70008e" stroke-width="1.71" d="M106.5,-791.27C106.5,-780.14 106.5,-765.41 106.5,-752.71"/>
# <polygon fill="#70008e" stroke="#70008e" stroke-width="1.71" points="110,-752.64 106.5,-742.64 103,-752.64 110,-752.64"/>
# <text text-anchor="middle" x="118" y="-763.87" font-family="Times,serif" font-size="12.00">20h</text>
# </g>
# <!-- &#45;3304176906226095080 -->
# <g id="node8" class="node">
# <title>&#45;3304176906226095080</title>
# <polygon fill="none" stroke="black" points="166,-657.47 47,-657.47 47,-621.47 166,-621.47 166,-657.47"/>
# <text text-anchor="middle" x="106.5" y="-636.37" font-family="Times,serif" font-size="12.00">Delivery Delayed</text>
# </g>
# <!-- 5332329727705121048&#45;&gt;&#45;3304176906226095080 -->
# <g id="edge7" class="edge">
# <title>5332329727705121048&#45;&gt;&#45;3304176906226095080</title>
# <path fill="none" stroke="#2500d9" stroke-width="1.24" d="M106.5,-706.27C106.5,-695.14 106.5,-680.41 106.5,-667.71"/>
# <polygon fill="#2500d9" stroke="#2500d9" stroke-width="1.24" points="110,-667.64 106.5,-657.64 103,-667.64 110,-667.64"/>
# <text text-anchor="middle" x="114.5" y="-678.87" font-family="Times,serif" font-size="12.00">6h</text>
# </g>
# <!-- &#45;2853046859372470595 -->
# <g id="node9" class="node">
# <title>&#45;2853046859372470595</title>
# <polygon fill="none" stroke="black" points="159,-572.47 54,-572.47 54,-536.47 159,-536.47 159,-572.47"/>
# <text text-anchor="middle" x="106.5" y="-551.37" font-family="Times,serif" font-size="12.00">Order Delayed</text>
# </g>
# <!-- &#45;3304176906226095080&#45;&gt;&#45;2853046859372470595 -->
# <g id="edge8" class="edge">
# <title>&#45;3304176906226095080&#45;&gt;&#45;2853046859372470595</title>
# <path fill="none" stroke="#fe0000" stroke-width="2.6" d="M106.5,-621.27C106.5,-610.14 106.5,-595.41 106.5,-582.71"/>
# <polygon fill="#fe0000" stroke="#fe0000" stroke-width="2.6" points="110,-582.64 106.5,-572.64 103,-582.64 110,-582.64"/>
# <text text-anchor="middle" x="115.5" y="-593.87" font-family="Times,serif" font-size="12.00">1D</text>
# </g>
# <!-- 3005095361485297306 -->
# <g id="node10" class="node">
# <title>3005095361485297306</title>
# <polygon fill="none" stroke="black" points="173.5,-487.47 39.5,-487.47 39.5,-451.47 173.5,-451.47 173.5,-487.47"/>
# <text text-anchor="middle" x="106.5" y="-466.37" font-family="Times,serif" font-size="12.00">

# %% [markdown]
# ## BPMN Process

# %%
# Discover BPMN model using inductive miner
bpmn_model = pm4py.discover_bpmn_inductive(log=parsed_events_df)

# Save the BPMN visualization with swimlanes based on resources
output_file = f"{working_directory}/example_2_bpmn.svg"
pm4py.save_vis_bpmn(bpmn_model, str(output_file), parameters={"format": "svg"}, rankdir="TB")
print(f"BPMN diagram saved to: {output_file}")

# Read and display diagram as HTML
with open(output_file, "r") as f:
    svg_content = f.read()
    display(HTML(svg_content))
# Out:
# BPMN diagram saved to: /home/garre/development/process-mining-demo/examples/example_2_bpmn.svg
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="221pt" height="1124pt"
#  viewBox="0.00 0.00 221.00 1124.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1120)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-1120 217,-1120 217,4 -4,4"/>
# <!-- 281097147036688 -->
# <g id="node1" class="node">
# <title>281097147036688</title>
# <ellipse fill="green" stroke="black" cx="106.5" cy="-1098" rx="18" ry="18"/>
# </g>
# <!-- 281097147030640 -->
# <g id="node2" class="node">
# <title>281097147030640</title>
# <polygon fill="none" stroke="black" points="195.5,-1044 17.5,-1044 17.5,-1008 195.5,-1008 195.5,-1044"/>
# <text text-anchor="middle" x="106.5" y="-1022.9" font-family="Times,serif" font-size="12.00">Purchase Order Submitted</text>
# </g>
# <!-- 281097147036688&#45;&gt;281097147030640 -->
# <g id="edge1" class="edge">
# <title>281097147036688&#45;&gt;281097147030640</title>
# <path fill="none" stroke="black" d="M106.5,-1079.7C106.5,-1071.98 106.5,-1062.71 106.5,-1054.11"/>
# <polygon fill="black" stroke="black" points="110,-1054.1 106.5,-1044.1 103,-1054.1 110,-1054.1"/>
# </g>
# <!-- 281097147037936 -->
# <g id="node3" class="node">
# <title>281097147037936</title>
# <polygon fill="none" stroke="black" points="175,-972 38,-972 38,-936 175,-936 175,-972"/>
# <text text-anchor="middle" x="106.5" y="-950.9" font-family="Times,serif" font-size="12.00">Quote Confirmation</text>
# </g>
# <!-- 281097147030640&#45;&gt;281097147037936 -->
# <g id="edge2" class="edge">
# <title>281097147030640&#45;&gt;281097147037936</title>
# <path fill="none" stroke="black" d="M106.5,-1007.7C106.5,-999.98 106.5,-990.71 106.5,-982.11"/>
# <polygon fill="black" stroke="black" points="110,-982.1 106.5,-972.1 103,-982.1 110,-982.1"/>
# </g>
# <!-- 281097147027424 -->
# <g id="node4" class="node">
# <title>281097147027424</title>
# <polygon fill="none" stroke="black" points="210,-900 3,-900 3,-864 210,-864 210,-900"/>
# <text text-anchor="middle" x="106.5" y="-878.9" font-family="Times,serif" font-size="12.00">Order Approved for Production</text>
# </g>
# <!-- 281097147037936&#45;&gt;281097147027424 -->
# <g id="edge3" class="edge">
# <title>281097147037936&#45;&gt;281097147027424</title>
# <path fill="none" stroke="black" d="M106.5,-935.7C106.5,-927.98 106.5,-918.71 106.5,-910.11"/>
# <polygon fill="black" stroke="black" points="110,-910.1 106.5,-900.1 103,-910.1 110,-910.1"/>
# </g>
# <!-- 281097147023680 -->
# <g id="node5" class="node">
# <title>281097147023680</title>
# <polygon fill="none" stroke="black" points="172.5,-828 40.5,-828 40.5,-792 172.5,-792 172.5,-828"/>
# <text text-anchor="middle" x="106.5" y="-806.9" font-family="Times,serif" font-size="12.00">Production Started</text>
# </g>
# <!-- 281097147027424&#45;&gt;281097147023680 -->
# <g id="edge4" class="edge">
# <title>281097147027424&#45;&gt;281097147023680</title>
# <path fill="none" stroke="black" d="M106.5,-863.7C106.5,-855.98 106.5,-846.71 106.5,-838.11"/>
# <polygon fill="black" stroke="black" points="110,-838.1 106.5,-828.1 103,-838.1 110,-838.1"/>
# </g>
# <!-- 281097146053120 -->
# <g id="node6" class="node">
# <title>281097146053120</title>
# <polygon fill="none" stroke="black" points="179.5,-756 33.5,-756 33.5,-720 179.5,-720 179.5,-756"/>
# <text text-anchor="middle" x="106.5" y="-734.9" font-family="Times,serif" font-size="12.00">QC Inspection Report</text>
# </g>
# <!-- 281097147023680&#45;&gt;281097146053120 -->
# <g id="edge5" class="edge">
# <title>281097147023680&#45;&gt;281097146053120</title>
# <path fill="none" stroke="black" d="M106.5,-791.7C106.5,-783.98 106.5,-774.71 106.5,-766.11"/>
# <polygon fill="black" stroke="black" points="110,-766.1 106.5,-756.1 103,-766.1 110,-766.1"/>
# </g>
# <!-- 281097146051008 -->
# <g id="node7" class="node">
# <title>281097146051008</title>
# <polygon fill="none" stroke="black" points="176.5,-684 36.5,-684 36.5,-648 176.5,-648 176.5,-684"/>
# <text text-anchor="middle" x="106.5" y="-662.9" font-family="Times,serif" font-size="12.00">Shipment Scheduled</text>
# </g>
# <!-- 281097146053120&#45;&gt;281097146051008 -->
# <g id="edge6" class="edge">
# <title>281097146053120&#45;&gt;281097146051008</title>
# <path fill="none" stroke="black" d="M106.5,-719.7C106.5,-711.98 106.5,-702.71 106.5,-694.11"/>
# <polygon fill="black" stroke="black" points="110,-694.1 106.5,-684.1 103,-694.1 110,-694.1"/>
# </g>
# <!-- 281097146054800 -->
# <g id="node8" class="node">
# <title>281097146054800</title>
# <polygon fill="none" stroke="black" points="172.5,-612 40.5,-612 40.5,-576 172.5,-576 172.5,-612"/>
# <text text-anchor="middle" x="106.5" y="-590.9" font-family="Times,serif" font-size="12.00">Loaded onto Truck</text>
# </g>
# <!-- 281097146051008&#45;&gt;281097146054800 -->
# <g id="edge7" class="edge">
# <title>281097146051008&#45;&gt;281097146054800</title>
# <path fill="none" stroke="black" d="M106.5,-647.7C106.5,-639.98 106.5,-630.71 106.5,-622.11"/>
# <polygon fill="black" stroke="black" points="110,-622.1 106.5,-612.1 103,-622.1 110,-622.1"/>
# </g>
# <!-- 281097146053552 -->
# <g id="node9" class="node">
# <title>281097146053552</title>
# <polygon fill="none" stroke="black" points="166,-540 47,-540 47,-504 166,-504 166,-540"/>
# <text text-anchor="middle" x="106.5" y="-518.9" font-family="Times,serif" font-size="12.00">Delivery Delayed</text>
# </g>
# <!-- 281097146054800&#45;&gt;281097146053552 -->
# <g id="edge8" class="edge">
# <title>281097146054800&#45;&gt;281097146053552</title>
# <path fill="none" stroke="black" d="M106.5,-575.7C106.5,-567.98 106.5,-558.71 106.5,-550.11"/>
# <polygon fill="black" stroke="black" points="110,-550.1 106.5,-540.1 103,-550.1 110,-550.1"/>
# </g>
# <!-- 281097146051776 -->
# <g id="node10" class="node">
# <title>281097146051776</title>
# <polygon fill="none" stroke="black" points="159,-468 54,-468 54,-432 159,-432 159,-468"/>
# <text text-anchor="middle" x="106.5" y="-446.9" font-family="Times,serif" font-size="12.00">Order Delayed</text>
# </g>
# <!-- 281097146053552&#45;&gt;281097146051776 -->
# <g id="edge9" class="edge">
# <title>281097146053552&#45;&gt;281097146051776</title>
# <path fill="none" stroke="black" d="M106.5,-503.7C106.5,-495.98 106.5,-486.71 106.5,-478.11"/>
# <polygon fill="black" stroke="black" points="110,-478.1 106.5,-468.1 103,-478.1 110,-478.1"/>
# </g>
# <!-- 281097146053072 -->
# <g id="node11" class="node">
# <title>281097146053072</title>
# <polygon fill="none" stroke="black" points="173.5,-396 39.5,-396 39.5,-360 173.5,-360 173.5,-396"/>
# <text text-anchor="middle" x="106.5" y="-374.9" font-family="Times,serif" font-size="12.00">Delivery Confirmed</text>
# </g>
# <!-- 281097146051776&#45;&gt;281097146053072 -->
# <g id="edge10" class="edge">
# <title>281097146051776&#45;&gt;281097146053072</title>
# <path fill="none" stroke="black" d="M106.5,-431.7C106.5,-423.98 106.5,-414.71 106.5,-406.11"/>
# <polygon fill="black" stroke="black" points="110,-406.1 106.5,-396.1 103,-406.1 110,-406.1"/>
# </g>
# <!-- 281097146050144 -->
# <g id="node12" class="node">
# <title>281097146050144</title>
# <polygon fill="none" stroke="black" points="193,-324 20,-324 20,-288 193,-288 193,-324"/>
# <text text-anchor="middle" x="106.5" y="-302.9" font-family="Times,serif" font-size="12.00">Delivery Delay Confirmed</text>
# </g>
# <!-- 281097146053072&#45;&gt;281097146050144 -->
# <g id="edge11" class="edge">
# <title>281097146053072&#45;&gt;281097146050144</title>
# <path fill="none" stroke="black" d="M106.5,-359.7C106.5,-351.98 106.5,-342.71 106.5,-334.11"/>
# <polygon fill="black" stroke="black" points="110,-334.1 106.5,-324.1 103,-334.1 110,-334.1"/>
# </g>
# <!-- 281097146050672 -->
# <g id="node13" class="node">
# <title>281097146050672</title>
# <polygon fill="none" stroke="black" points="201.5,-252 11.5,-252 11.5,-216 201.5,-216 201.5,-252"/>
# <text text-anchor="middle" x="106.5" y="-230.9" font-family="Times,serif" font-size="12.00">Foundation Footers Installed</text>
# <
